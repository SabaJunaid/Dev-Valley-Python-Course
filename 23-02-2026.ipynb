# %% [markdown]
# ## 23-02-2026

# %%
# make calculator user prespective
num1 = int(input("Enter first number: "))
operator = input("Enter operator (+, -, *, /): ")
num2 = float(input("Enter second number: "))

if operator == "+":
    print("Result =", num1 + num2)

elif operator == "-":
    print("Result =", num1 - num2)

elif operator == "*":
    print("Result =", num1 * num2)

elif operator == "/":
    if num2 != 0:
        print("Result =", num1 / num2)
    else:
        print("Error! Division by zero.")

else:
    print("Invalid operator!")
# Out:
# Result = 12.0

# %%
# calculate electricity bill
units = int(input("Enter electricity units: "))

if units <= 100:
    bill = units * 5

elif units <= 200:
    bill = units * 10

elif units <= 300:
    bill = units * 15

else:
    bill = units * 20

print("Your electricity bill is Rs:", bill)
# Out:
# Your electricity bill is Rs: 6900

# %%
# calclulate discount
amount = int(input("Enter total amount: "))
if amount <= 1000:
    discount = amount * 0.05

elif amount <= 5000:
    discount = amount * 0.10
else:
    discount = amount * 0.20

final_price = amount - discount

print("Discount is:", discount)
print("Final amount to pay:", final_price)
# Out:
# Discount is: 300.0
# Final amount to pay: 2700.0

# %%
# Calculate bonus based on years of service
year = int(input("Enetr total years of service:"))
if year<=10:
    bonus = 10000
elif year<=15:
    bonus = 15000
else:
    print("not eligible for bonus")

# %%
year = int(input("Enter total years of service: "))

if year <= 10:
    bonus = 10000
elif year <= 15:
    bonus = 15000
else:
    bonus = 20000  # or any value you want for >15 years

print("Your bonus is:", bonus)
# Out:
# Your bonus is: 15000

# %%
# hoops
