# %% [markdown]
# ## 17/02/2026

# %%
list1= ["apple", "orange", "kiwi"]
list1.append("banana")
print(list1)
list1.append("melon")
print(list1)
list1.pop()
print(list1)
list1.reverse()
print(list1)
list1.insert(0, "grapes")
print(list1)
list1.remove("apple")
print(list1)
print(len(list1))
# Out:
# ['apple', 'orange', 'kiwi', 'banana']
# ['apple', 'orange', 'kiwi', 'banana', 'melon']
# ['apple', 'orange', 'kiwi', 'banana']
# ['banana', 'kiwi', 'orange', 'apple']
# ['grapes', 'banana', 'kiwi', 'orange', 'apple']
# ['grapes', 'banana', 'kiwi', 'orange']
# 4

# %%
def function():
    input_name= str(input("enter your name"))
    print("hi", input_name, "Welcome to GCUF login page")
function()
# Out:
# hi Saaba Welcome to GCUF login page

# %%
# concatinate, append, slice, index, len, upper, lower, replace, remove, add,
