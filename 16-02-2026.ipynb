# %% [markdown]
# ## Assigning/Values/to/Variables

# %%
a=2.3
b=9.3
c=4.2
d=3.3
e=2.5
print(a,b,c,d,e)
# Out:
# 2.3 9.3 4.2 3.3 2.5

# %%
a=1
b=2
c=3
d=4
e=5
print(a,b,c,d,e)
# Out:
# 1 2 3 4 5

# %%
chr="saba"
print(chr)
# Out:
# saba

# %%
chr="Ahmad"
print(chr)
# Out:
# Ahmad

# %%
chr="Aneeqa"
print(chr)
# Out:
# Aneeqa

# %%
chr="school"
print(chr)
# Out:
# school

# %%
chr="world"
print(chr)
# Out:
# world

# %%
a=1
b=2
print(a>b)
# Out:
# False

# %%
a=10
b=45
print(45>a)
# Out:
# True

# %%
x=45
b=20
print(b<x)
# Out:
# True

# %%
a=3
b=15
print(a>b)
# Out:
# False

# %%
number=[1,2,3,4,5,6]
print(number)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# operations
