# %%
import pandas as pd

# %% [markdown]
# ## Data Reading

# %%
df=pd.read_csv(r'C:\Users\saba\Downloads\data.csv')
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# ## Head() shows 1st 5 rows

# %%
# undefined number of rows e.g, when number is not given head() will print only first 5 rows
print(df.head())
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
# defiined number of rows e.g, 12
print(df.head(12))
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7

# %% [markdown]
# ## Tail() shows last 5 rows

# %%
# tail() will print last 5 rows
print(df.tail())
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 27        60  '2020/12/27'     92       118     241.0
# 28        60  '2020/12/28'    103       132       NaN
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %% [markdown]
# ## Check shape(rows and column)

# %%
print(df.shape)
# Out:
# (32, 5)

# %% [markdown]
# ## Display column names

# %%
df.columns
# Out:
# Index(['Duration', 'Date', 'Pulse', 'Maxpulse', 'Calories'], dtype='str')

# %% [markdown]
# # Check data type of all column

# %%
df.dtypes
# Out:
# Duration      int64
# Date            str
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %% [markdown]
# ## Statistical Summery

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %% [markdown]
# ## Maximum Pulse value

# %%
df["Pulse"].max()
# Out:
# np.int64(130)

# %% [markdown]
# ## Minimum Duration

# %%
df["Duration"].min()
# Out:
# np.int64(30)

# %% [markdown]
# # Average Caouries burned

# %%
df["Calories"].mean()
# Out:
# np.float64(304.68)

# %% [markdown]
# ## Display max_rows

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %% [markdown]
# ## info()

# %%
# Gives you more information about data like(non-null values, columns, data type)
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     str
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), str(1)
# memory usage: 1.4 KB
# None

# %% [markdown]
# ## DATA CLEANING TASKS

# %% [markdown]
# ## Replace Empty Cells using fillna() using specific column

# %%
# fillna() will replace null value instead removing entire cell
df.fillna({"Calories": 130}, inplace=True) # but you have to specify the column in which you want to make changes 
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.fillna({'Date':'Unknown'}, inplace=True) # this will make changes in specific column (Date column only)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# ## Replace empty cells using Mean(), Median(), Mode()

# %% [markdown]
# ## Mean()

# %%
x=df["Calories"].mean() # specify the column you want to calculate mean. 
df.fillna({"Calories":x}, inplace=True )
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# ## Median()

# %%
x = df["Calories"].median()

df.fillna({"Calories": x}, inplace=True)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# ## Mode()

# %%
X=df["Calories"].mode()
df.fillna({"Calories": 120}, inplace=True)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# ## Removing entire cells containing NaN values

# %%
# if you dont want to replace empty values another method is to delet entire row containing Null value 
# for removing entrire row with NaN value use df1=df.dropna() this will return new dataframe without changing original dataframe
# if you want to make changes in original dataframe without using df1 use df.dropna(inplace=True)

# %% [markdown]
# ## Wrong format

# %%
# Row 22 and 26 have wrong date format 
# to_datetime() is used to fix this
df1=pd.read_csv(r'c:\Users\saba\Downloads\data.csv')
df1
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# ## Date column into datetime format

# %%
# to_datetime() function fix wrong date to default pandas format
df1['Date'] = pd.to_datetime(df1['Date'], format='mixed')
df1
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %% [markdown]
# ## Identifying missing values

# %%
print(df1.isnull().sum())
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %% [markdown]
# #  Replacing missing Calories values with the mean Calories

# %%
df_mean = df1["Calories"].mean()
df1["Calories"].fillna(df_mean)
# Out:
# 0     409.10
# 1     479.00
# 2     340.00
# 3     282.40
# 4     406.00
# 5     300.00
# 6     374.00
# 7     253.30
# 8     195.10
# 9     269.00
# 10    329.30
# 11    250.70
# 12    250.70
# 13    345.30
# 14    379.30
# 15    275.00
# 16    215.20
# 17    300.00
# 18    304.68
# 19    323.00
# 20    243.00
# 21    364.20
# 22    282.00
# 23    300.00
# 24    246.00
# 25    334.50
# 26    250.00
# 27    241.00
# 28    304.68
# 29    280.00
# 30    380.30
# 31    243.00
# Name: Calories, dtype: float64

# %% [markdown]
# ## Finding and removing duplicate rows

# %%
# Finding duplicates
df1.duplicated().sum()
# Out:
# np.int64(1)

# %%
# Removing duplicates
df1.drop_duplicates()
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# 17        60 2020-12-17    100       120     300.0
# ...

# %%
# Another way to find and remove duplictaes
df1.drop_duplicates(inplace=True)
df1
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# 17        60 2020-12-17    100       120     300.0
# ...

# %% [markdown]
# # Detecting and fixing incorrect Durtaion (450) minutes

# %%
df1.Duration.replace(450,45)
# Out:
# 0     60
# 1     60
# 2     60
# 3     45
# 4     45
# 5     60
# 6     60
# 7     45
# 8     30
# 9     60
# 10    60
# 11    60
# 13    60
# 14    60
# 15    60
# 16    60
# 17    60
# 18    45
# 19    60
# 20    45
# 21    60
# 22    45
# 23    60
# 24    45
# 25    60
# 26    60
# 27    60
# 28    60
# 29    60
# 30    60
# 31    60
# Name: Duration, dtype: int64

# %% [markdown]
# # Remove rows where Date is missing

# %%
# NaT can be handled by removing entire row using bdropna()
df1.dropna(subset=['Date'], inplace = True)
df1
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# 17        60 2020-12-17    100       120     300.0
# ...

# %% [markdown]
# ## Replace the date format "20201226" with proper datetime format

# %% [markdown]
# # Replace for specific columns

# %%
df1=pd.read_csv(r'c:\Users\saba\Downloads\data.csv')
df1
new_df = df["Calories"].fillna(130)
new_df
# Out:
# 0     409.1
# 1     479.0
# 2     340.0
# 3     282.4
# 4     406.0
# 5     300.0
# 6     374.0
# 7     253.3
# 8     195.1
# 9     269.0
# 10    329.3
# 11    250.7
# 12    250.7
# 13    345.3
# 14    379.3
# 15    275.0
# 16    215.2
# 17    300.0
# 18    130.0
# 19    323.0
# 20    243.0
# 21    364.2
# 22    282.0
# 23    300.0
# 24    246.0
# 25    334.5
# 26    250.0
# 27    241.0
# 28    130.0
# 29    280.0
# 30    380.3
# 31    243.0
# Name: Calories, dtype: float64

# %%
df1["Date"] = pd.to_datetime(df1["Date"], format='mixed')
df1["Date"]
# Out:
# 0    2020-12-01
# 1    2020-12-02
# 2    2020-12-03
# 3    2020-12-04
# 4    2020-12-05
# 5    2020-12-06
# 6    2020-12-07
# 7    2020-12-08
# 8    2020-12-09
# 9    2020-12-10
# 10   2020-12-11
# 11   2020-12-12
# 12   2020-12-12
# 13   2020-12-13
# 14   2020-12-14
# 15   2020-12-15
# 16   2020-12-16
# 17   2020-12-17
# 18   2020-12-18
# 19   2020-12-19
# 20   2020-12-20
# 21   2020-12-21
# 22          NaT
# 23   2020-12-23
# 24   2020-12-24
# 25   2020-12-25
# 26   2020-12-26
# 27   2020-12-27
# 28   2020-12-28
# 29   2020-12-29
# 30   2020-12-30
# 31   2020-12-31
# Name: Date, dtype: datetime64[us]

# %% [markdown]
# ## Select rows where Duration is greater than 60 minutes

# %%
df1[df1["Duration"] > 60]
# Out:
#    Duration       Date  Pulse  Maxpulse  Calories
# 7       450 2020-12-08    104       134     253.3

# %% [markdown]
# ## Select rows where Pulse > 110

# %%
df1[df1["Pulse"] > 110]
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 1         60 2020-12-02    117       145     479.0
# 4         45 2020-12-05    117       148     406.0
# 23        60 2020-12-23    130       101     300.0

# %% [markdown]
# # Filter rows where Calories burned are greater than 350

# %%
df1[df1["Calories"] > 350]
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 4         45 2020-12-05    117       148     406.0
# 6         60 2020-12-07    110       136     374.0
# 14        60 2020-12-14    104       132     379.3
# 21        60 2020-12-21    108       131     364.2
# 30        60 2020-12-30    102       129     380.3

# %% [markdown]
# ## Select rows where Pulse is between 100 and 110

# %%
df1[(df1["Pulse"] >= 100) & (df1["Pulse"] <= 110)]
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 17        60 2020-12-17    100       120     300.0
# 19        60 2020-12-19    103       123     323.0
# 21        60 2020-12-21    108       131     364.2
# 22        45        NaT    100       119     282.0
# 24        45 2020-12-24    105       132     246.0
# ...

# %% [markdown]
# # Display only Duration and Calories columns

# %%
df1[["Duration","Calories"]]
# Out:
#     Duration  Calories
# 0         60     409.1
# 1         60     479.0
# 2         60     340.0
# 3         45     282.4
# 4         45     406.0
# 5         60     300.0
# 6         60     374.0
# 7        450     253.3
# 8         30     195.1
# 9         60     269.0
# 10        60     329.3
# 11        60     250.7
# 12        60     250.7
# 13        60     345.3
# 14        60     379.3
# 15        60     275.0
# 16        60     215.2
# 17        60     300.0
# 18        45       NaN
# 19        60     323.0
# 20        45     243.0
# 21        60     364.2
# 22        45     282.0
# 23        60     300.0
# 24        45     246.0
# 25        60     334.5
# 26        60     250.0
# 27        60     241.0
# 28        60       NaN
# 29        60     280.0
# 30        60     380.3
# 31        60     243.0

# %% [markdown]
# ## Calculate the average Pulse for the dataset

# %%
df1["Pulse"].mean()
# Out:
# np.float64(103.5)

# %% [markdown]
# ## Find the day with the highest Calories burned.

# %%
df1.loc[df1["Calories"].idxmax(), "Date"]
# Out:
# Timestamp('2020-12-02 00:00:00')

# %% [markdown]
# ## Find the total Calories burned in December.

# %%
df1["Calories"].sum()
# Out:
# np.float64(9140.4)

# %% [markdown]
# ## Calculate the average Duration of workouts.

# %%
df1["Duration"].mean().roun
# Out:
# np.float64(68.4375)

# %% [markdown]
# ##  Find the maximum Maxpulse value

# %%
df1["Maxpulse"].max()
# Out:
# np.int64(175)

# %% [markdown]
# ## Sorting & Grouping Tasks

# %% [markdown]
# ## Sort the dataset by Calories burned (descending).

# %%
df1.sort_values(by="Calories", ascending=False)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 1         60 2020-12-02    117       145     479.0
# 0         60 2020-12-01    110       130     409.1
# 4         45 2020-12-05    117       148     406.0
# 30        60 2020-12-30    102       129     380.3
# 14        60 2020-12-14    104       132     379.3
# 6         60 2020-12-07    110       136     374.0
# 21        60 2020-12-21    108       131     364.2
# 13        60 2020-12-13    106       128     345.3
# 2         60 2020-12-03    103       135     340.0
# 25        60 2020-12-25    102       126     334.5
# 10        60 2020-12-11    103       147     329.3
# 19        60 2020-12-19    103       123     323.0
# 23        60 2020-12-23    130       101     300.0
# 5         60 2020-12-06    102       127     300.0
# 17        60 2020-12-17    100       120     300.0
# 3         45 2020-12-04    109       175     282.4
# 22        45        NaT    100       119     282.0
# ...

# %% [markdown]
# ## 30. Sort the dataset by Pulse (ascending).

# %%
df1.sort_values(by="Pulse", ascending=True)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 18        45 2020-12-18     90       112       NaN
# 27        60 2020-12-27     92       118     241.0
# 31        60 2020-12-31     92       115     243.0
# 20        45 2020-12-20     97       125     243.0
# 15        60 2020-12-15     98       123     275.0
# 9         60 2020-12-10     98       124     269.0
# 16        60 2020-12-16     98       120     215.2
# 11        60 2020-12-12    100       120     250.7
# 17        60 2020-12-17    100       120     300.0
# 22        45        NaT    100       119     282.0
# 29        60 2020-12-29    100       132     280.0
# 12        60 2020-12-12    100       120     250.7
# 26        60 2020-12-26    100       120     250.0
# 5         60 2020-12-06    102       127     300.0
# 30        60 2020-12-30    102       129     380.3
# 25        60 2020-12-25    102       126     334.5
# 28        60 2020-12-28    103       132       NaN
# ...

# %% [markdown]
# ## Group the data by Duration and calculate average Pulse

# %%
df1.groupby("Duration")["Pulse"].mean()
# Out:
# Duration
# 30     109.000
# 45     103.000
# 60     103.375
# 450    104.000
# Name: Pulse, dtype: float64

# %% [markdown]
# ##  Find the top 5 workouts with the highest Calories burned.

# %%
df1.nlargest(5, "Calories")
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 1         60 2020-12-02    117       145     479.0
# 0         60 2020-12-01    110       130     409.1
# 4         45 2020-12-05    117       148     406.0
# 30        60 2020-12-30    102       129     380.3
# 14        60 2020-12-14    104       132     379.3

# %% [markdown]
# ## Aggregation and Statistics

# %% [markdown]
# ## Calculate average Pulse.

# %%
df1["Pulse"].mean()
# Out:
# np.float64(103.5)

# %% [markdown]
# ## Calculate average Duration

# %%
df1["Duration"].mean()
# Out:
# np.float64(68.4375)

# %% [markdown]
# ## Find maximum Calories burned.

# %%
df1["Calories"].max()
# Out:
# np.float64(479.0)

# %% [markdown]
# ## Find minimum Pulse.

# %%
df1["Pulse"].min()
# Out:
# np.int64(90)

# %% [markdown]
# ## Find total Calories burned.

# %%
df1["Calories"].sum()
# Out:
# np.float64(9140.4)

# %% [markdown]
# ## Count how many workouts have Duration = 60.

# %%
df1[df1["Duration"] == 60].shape[0]
# Out:
# 24

# %% [markdown]
# ## Group by operations

# %% [markdown]
# ## Group dataset by Duration and calculate average Calories.

# %%
df1.groupby("Duration")["Calories"].mean()
# Out:
# Duration
# 30     195.10000
# 45     291.88000
# 60     314.46087
# 450    253.30000
# Name: Calories, dtype: float64

# %% [markdown]
# ## Group by Duration and calculate average Pulse.

# %%
df1.groupby("Duration")["Pulse"].mean()
# Out:
# Duration
# 30     109.000
# 45     103.000
# 60     103.375
# 450    104.000
# Name: Pulse, dtype: float64

# %% [markdown]
# ## Find maximum Pulse for each Duration group.

# %%
df1.groupby("Duration")["Pulse"].max()
# Out:
# Duration
# 30     109
# 45     117
# 60     130
# 450    104
# Name: Pulse, dtype: int64

# %% [markdown]
# ## Count number of workouts per Duration category.

# %%
df1.groupby("Duration").size()
# Out:
# Duration
# 30      1
# 45      6
# 60     24
# 450     1
# dtype: int64

# %% [markdown]
# ## Mini Project Challenge

# %% [markdown]
# ## Which day had the highest calorie burn?

# %%
df1.loc[df1["Calories"].idxmax(), "Date"]
# Out:
# Timestamp('2020-12-02 00:00:00')

# %% [markdown]
# ## What is the average workout duration?

# %%
df1["Duration"].mean()
# Out:
# np.float64(68.4375)

# %% [markdown]
# ## Which workout had the highest Pulse rate?

# %%
df1.loc[df1["Pulse"].idxmax()]
# Out:
# Duration                     60
# Date        2020-12-23 00:00:00
# Pulse                       130
# Maxpulse                    101
# Calories                  300.0
# Name: 23, dtype: object

# %% [markdown]
# ## What is the average Calories burned per minute?

# %%
(df1["Calories"] / df1["Duration"]).mean()
# Out:
# np.float64(5.3346888888888895)
