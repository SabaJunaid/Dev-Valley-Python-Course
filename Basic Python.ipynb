# %% [markdown]
# ## Self learning from begning

# %%
# python can print directly whatever in written in print()
print("hello")
# Out:
# hello

# %%
# assigning value to variable
a=10
b=15
print(a+b)
# Out:
# 25

# %%
a = "saba"
print(a)
# Out:
# saba

# %%
# checking indentation 4 or more
if 5<2:
    print("five is greater than two")
else:
                  print("give less tahn two")
# Out:
# give less tahn two

# %%
# same block of must must have same indentation
if 5 > 2:
          print("Five is greater than two!")
if 5<2:
 print("false")
# Out:
# Five is greater than two!

# %%
# Semicolan as separator (more than one print on same line but multiline output)
print("saba"); print("junaid")
# Out:
# saba
# junaid

# %%
# multiline commnad (line separator)
print("learning python is fun")
print("i am saba")
print("i  am learning python")
# Out:
# learning python is fun
# i am saba
# i  am learning python

# %%
# double quotes text
print("i am saba")
# Out:
# i am saba

# %%
# single quote text 
print('i am saba')
# Out:
# i am saba

# %%
# using end parameter (multiline print, one output)
print("Hello World!", end=" ")
print("I am saba.")
# Out:
# Hello World! I am saba.

# %%
print("Hello" , end=" ")
print("I am saba")
# Out:
# Hello I am saba

# %%
print("hy there!" , end=" ")
print("i am using whatsapp")
# Out:
# hy there! i am using whatsapp

# %%
print(3)
print(500 , end= "")
print(120)
# Out:
# 3
# 500120

# %%
# math within print function
print(5*8)
# Out:
# 40

# %%
# separating text and number with comma
print("I am Ahsan. I am" , 12)
# Out:
# I am Ahsan. I am 12

# %%
print("i am", 25)
# Out:
# i am 25

# %%
# print("hello saba")
print("i am girl")
# above statement is print statement #print("hello saba") python ignored it because of # only i am girl statement will be executed
# Out:
# i am girl

# %%
# this is miltiline comment
# written in 
# more than one line
print(" i am a Phd student")
# Out:
#  i am a Phd student

# %%
"""
This is a comment 
written in
more than just one line
"""
print("i am pakistani")
# Out:
# i am pakistani

# %%
# casting (Specifying data type of variable)
u = str(5)
print(u)
# Out:
# 5

# %%
y = int(3.0)
print(y)
# Out:
# 3

# %%
z = float(3)
print(z)
# Out:
# 3.0

# %%
# Getting the type of variable
x=4
b="saba"
c=3.5
print(type(x))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
# case sensitivity of variable
x=3   # x in lower case 
X=3   # X in upper case
print(x+X)
# Out:
# 6

# %%
# assign values to multiple variables in one line
x , y, z = "orange", "Banana", "cherry"
print(x)
print(y)
print(z)
# Out:
# orange
# Banana
# cherry

# %%
# assign the same value to multiple variables in one line
x = y = z = "orange"
print(x)
print(y)
print(z)
# Out:
# orange
# orange
# orange

# %%
# unpacking a list
fruits = ["Apple", "Banana", "Grapes"]
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# Apple
# Banana
# Grapes

# %%
# output multiple variables, separated by a comma
x = "Python "
y = "is "
z = "awesome"
print(x, y, z)
print(x  + y + z)
# Out:
# Python  is  awesome
# Python is awesome

# %%
#  (+) character works as a mathematical operator
x=10
y=10
print(x+y)
# Out:
# 20

# %%
# to output multiple variables types like num and str + sign cant combine but comma can
x=5
y="saba"
print(x,y)
# Out:
# 5 saba

# %%
# using type () function
x=6
y=3.5
c='56'
print(type(x))
print(type(y))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
# Import the random module, and display a random number from 1 to 9
import random
print(random.randrange(1, 10))
# Out:
# 4

# %%
# Convert from one type to another
x= 3
y= 3.7
z= 3j
a= float(x)
b= int(3.7)
c= complex(3) # complex can not be converted to another numeric data type
print(a)
print(b)
print(c)
print(type (a))
print(type (b))
print(type (c))
# Out:
# 3.0
# 3
# (3+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>
